# %%
import pandas as pd
import json

df = pd.read_csv("C:/Users/kevin/ETL/Postgres/kaggle/glassdoor.csv", delimiter = ',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Columns: 163 entries, benefits.benefitRatingDecimal to wwfu
# dtypes: bool(11), float64(35), int64(23), object(94)
# memory usage: 193.4+ MB

# %% [markdown]
# Este dataset dispone de 165.290 filas con 163 columnas, de lso cuales hay 23 columnas de numeros enteros, 35 decimales, 11 booleanos y 94 tipo objeto (texto).

# %%
df.head()
# Out:
#    benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.0             2801.0               2801.0
# 1                            4.0             2802.0               2802.0
# 2                            0.0             2803.0               2803.0
# 3                            0.0             2804.0               2804.0
# 4                            0.0             2805.0               2805.0
#
#    benefits.numRatings benefits.employerSummary  breadCrumbs  \
# 0                    0                      NaN         2801
# 1                    3                      NaN         2802
# 2                    0                      NaN         2803
# 3                    0                      NaN         2804
# 4                    0                      NaN         2805
#
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# 0                      -1              2183810            Modus Group
# 1                      -1                10416   Boehringer Ingelheim
# 2                      -1              1043373        Immobiliare.it
# 3                      -1              2226886                  Codup
# 4                      -1               851555  Markelytics Solutions
#
#   gaTrackerData.empSize  gaTrackerData.expired  \
# 0              501-1000                  False
# 1              10000--1                  False
# 2               201-500                  False
# 3                  1-50                  False
# 4               201-500                  False
#
#                   gaTrackerData.industry  gaTrackerData.industryId  \
# 0  Investment Banking & Asset Management                    200053
# 1              Biotech & Pharmaceuticals                    200021
# 2                                    NaN                         0
# 3                                    NaN                         0
# 4                             Consulting                    200028
#
#    gaTrackerData.jobId.long  gaTrackerData.jobId.int  \
# 0              3.227100e+09                      NaN
# 1              3.406582e+09                      NaN
# 2              3.230738e+09                      NaN
# 3              3.406677e+09                      NaN
# 4              3.201516e+09                      NaN
#
#                               gaTrackerData.jobTitle gaTrackerData.location  \
# 0                 Biogas Project Development Manager                 Warsaw
# 1  Quality Manager - Boehringer Ingelheim Healthc...                    NaN
# 2     Senior Software Engineer (PHP, Elixir, Python)                 Milano
# 3                                Senior SQA Engineer                Karachi
# 4                                   Research Manager              Bengaluru
#
#    gaTrackerData.locationId gaTrackerData.locationType  \
# 0                   3094484                       CITY
# 1                   3183562                       CITY
# 2                   2802090                       CITY
# 3                   3212296                       CITY
# 4                   2940587                       CITY
#
#   gaTrackerData.pageRequestGuid.guid  gaTrackerData.pageRequestGuid.guidValid  \
# 0   0000016e56d0b5f2b16c3aea720c55ae                                     True
# 1   0000016e56d0b5cfa19a4b2ba225a2ee                                     True
# 2   0000016e56d0b5c58f39733898e10986                                     True
# 3   0000016e56d0b5bca1733da6de4f4098                                     True
# 4   0000016e56d0b5ba9a6c4efc3844657c                                     True
#
#    gaTrackerData.pageRequestGuid.part1  gaTrackerData.pageRequestGuid.part2  \
# 0                        1573414548978                 -5662085852901386834
# 1                        1573414548943                 -6802041636413660434
# 2                        1573414548933                 -8126337365693101690
# 3                        1573414548924                 -6813034024377827176
# 4                        1573414548922                 -7319388449201166980
#
#         gaTrackerData.sector  gaTrackerData.sectorId  \
# 0                    Finance                   10010
# 1  Biotech & Pharmaceuticals                   10005
# 2                        NaN                       0
# 3                        NaN                       0
# 4          Business Services                   10006
#
#   gaTrackerData.profileConversionTrackingParams.trackingCAT  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    gaTrackerData.profileConversionTrackingParams.trackingSRC  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    gaTrackerData.profileConversionTrackingParams.trackingXSP  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    gaTrackerData.jobViewTrackingResult.jobViewDisplayTimeMillis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   gaTrackerData.jobViewTrackingResult.requiresTracking  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   gaTrackerData.jobViewTrackingResult.trackingUrl  header.adOrderId  \
# 0                                             NaN             14295
# 1                                             NaN             43297
# 2                                             NaN            437149
# 3                                             NaN            389273
# 4                                             NaN            437149
#
#   header.advertiserType  header.applicationId  header.applyButtonDisabled  \
# 0               GENERAL                     0                       False
# 1               GENERAL                     0                       False
# 2               GENERAL                     0                       False
# 3             JOB_BOARD                     0                       False
# 4               GENERAL                     0                       False
#
#                                      header.applyUrl  header.blur  \
# 0  /partner/jobListing.htm?pos=101&ao=14295&tgt=A...         True
# 1  /partner/jobListing.htm?pos=101&ao=43297&s=58&...         True
# 2  /partner/jobListing.htm?pos=101&ao=437149&s=58...         True
# 3  /partner/jobListing.htm?pos=101&ao=389273&s=58...         True
# 4  /partner/jobListing.htm?pos=101&ao=437149&s=58...         True
#
#                            header.coverPhoto  header.easyApply  \
# 0  /static/img/banners/default-ei-banner.jpg              True
# 1  /static/img/banners/default-ei-banner.jpg             False
# 2  /static/img/banners/default-ei-banner.jpg             False
# 3  /static/img/banners/default-ei-banner.jpg             False
# 4  /static/img/banners/default-ei-banner.jpg             False
#
#    header.employerId          header.employerName  header.expired  \
# 0            2183810                  Modus Group           False
# 1              10416         Boehringer Ingelheim           False
# 2            1043373               Immobiliare.it           False
# 3            2226886                        Codup           False
# 4             851555  MARKELYTICS SOLUTIONS INDIA           False
#
#    header.gocId  header.hideCEOInfo  \
# 0            -1               False
# 1            -1               False
# 2            -1               False
# 3            -1               False
# 4            -1               False
#
#                                      header.jobTitle  header.locId  \
# 0                 Biogas Project Development Manager       3094484
# 1  Quality Manager - Boehringer Ingelheim Healthc...       3183562
# 2     Senior Software Engineer (PHP, Elixir, Python)       2802090
# 3                                Senior SQA Engineer       3212296
# 4                                   Research Manager       2940587
#
#   header.location header.locationType  \
# 0          Warsaw                   C
# 1           Porto                   C
# 2           Milan                   C
# 3         Karāchi                   C
# 4       Bengaluru                   C
#
#                                          header.logo  \
# 0  https://media.glassdoor.com/sqls/2183810/modus...
# 1  https://media.glassdoor.com/sqls/10416/boehrin...
# 2  https://media.glassdoor.com/sqls/1043373/immob...
# 3                                                NaN
# 4  https://media.glassdoor.com/sqls/851555/markel...
#
#                                        header.logo2x  header.organic  \
# 0  https://media.glassdoor.com/sqlm/2183810/modus...            True
# 1  https://media.glassdoor.com/sqlm/10416/boehrin...            True
# 2  https://media.glassdoor.com/sqlm/1043373/immob...            True
# 3                                                NaN           False
# 4  https://media.glassdoor.com/sqlm/851555/markel...            True
#
#                                   header.overviewUrl header.posted  \
# 0  /Overview/Working-at-Modus-Group-EI_IE2183810....  Oct 24, 2019
# 1  /Overview/Working-at-Boehringer-Ingelheim-EI_I...   Nov 4, 2019
# 2  /Overview/Working-at-Immobiliare-it-EI_IE10433...  Oct 28, 2019
# 3  /Overview/Working-at-Codup-EI_IE2226886.11,16.htm   Nov 4, 2019
# 4  /Overview/Working-at-MARKELYTICS-SOLUTIONS-IND...   Nov 1, 2019
#
#    header.rating  header.saved  header.savedJobId  header.sgocId  \
# 0           -0.1         False                  0              0
# 1            3.8         False                  0              0
# 2            2.4         False                  0              0
# 3            1.5         False                  0              0
# 4            3.5         False                  0              0
#
#    header.sponsored  header.userAdmin header.uxApplyType header.featuredVideo  \
# 0             False             False                API                  NaN
# 1             False             False                NaN                  NaN
# 2             False             False                NaN                  NaN
# 3             False             False                NaN                  NaN
# 4             False             False                NaN                  NaN
#
#   header.normalizedJobTitle header.urgencyLabel header.urgencyLabelForMessage  \
# 0                       NaN                 NaN                           NaN
# 1                       NaN                 NaN                           NaN
# 2                       NaN                 NaN                           NaN
# 3                       NaN                 NaN                           NaN
# 4                       NaN                 NaN                           NaN
#
#   header.urgencyMessage header.needsCommission  header.payHigh  header.payLow  \
# 0                   NaN                    NaN             NaN            NaN
# 1                   NaN                    NaN             NaN            NaN
# 2                   NaN                    NaN             NaN            NaN
# 3                   NaN                    NaN             NaN            NaN
# 4                   NaN                    NaN             NaN            NaN
#
#    header.payMed header.payPeriod  header.salaryHigh  header.salaryLow  \
# 0            NaN              NaN                NaN               NaN
# 1            NaN              NaN                NaN               NaN
# 2            NaN              NaN                NaN               NaN
# 3            NaN              NaN                NaN               NaN
# 4            NaN              NaN                NaN               NaN
#
#   header.salarySource                                    job.description  \
# 0                 NaN  We are the drivers of the future who offer a g...
# 1                 NaN  <strong></strong>\n<br/><br/>\n<strong></stron...
# 2                 NaN  Dottori.it &egrave; il motore di ricerca che t...
# 3                 NaN  Codup is looking for a Senior SQA Engineer for...
# 4                 NaN  <strong>Department:</strong> Research &amp; Op...
#
#       job.discoverDate  job.eolHashCode  job.importConfigId  \
# 0  2019-10-24T04:52:23         -2041513               75613
# 1  2019-11-04T03:59:14        320139505               91874
# 2  2019-10-28T12:48:55      -1836661938              252306
# 3  2019-11-04T07:00:20        776027520              277822
# 4  2019-11-01T13:40:48        928824553              252303
#
#    job.jobReqId.long  job.jobReqId.int             job.jobSource  \
# 0       4.101124e+09               NaN            WorkableHR.com
# 1       4.202175e+09               NaN                     taleo
# 2       4.069122e+09               NaN  Indeed XML Feed Employer
# 3       4.202320e+09               NaN    Indeed XML Feed Dradis
# 4       4.042579e+09               NaN  Indeed XML Feed Employer
#
#    job.jobTitleId  job.listingId.long  job.listingId.int map.country  \
# 0              -1        3.227100e+09                NaN      Poland
# 1              -1        3.406582e+09                NaN         NaN
# 2              -1        3.230738e+09                NaN       Italy
# 3           35043        3.406677e+09                NaN          PK
# 4           33240        3.201516e+09                NaN          IN
#
#         map.employerName  map.lat  map.lng map.location map.address  \
# 0            Modus Group  52.2500  21.0000       Warsaw         NaN
# 1   Boehringer Ingelheim  41.1500  -8.6167        Porto         NaN
# 2        Immobiliare.it   45.4667   9.2000        Milan         NaN
# 3                  Codup  24.8667  67.0500      Karāchi         NaN
# 4  Markelytics Solutions  12.9670  77.5873    Bengaluru         NaN
#
#   map.postalCode                           overview.allBenefitsLink  \
# 0            NaN  /Benefits/Modus-Group-UK-Benefits-EI_IE2183810...
# 1            NaN  /Benefits/Boehringer-Ingelheim-UK-Benefits-EI_...
# 2            NaN  /Benefits/Immobiliare-it-UK-Benefits-EI_IE1043...
# 3            NaN  /Benefits/Codup-UK-Benefits-EI_IE2226886.0,5_I...
# 4            NaN  /Benefits/Markelytics-Solutions-UK-Benefits-EI...
#
#                               overview.allPhotosLink  \
# 0     /Photos/Modus-Group-Office-Photos-E2183810.htm
# 1  /Photos/Boehringer-Ingelheim-Office-Photos-E10...
# 2  /Photos/Immobiliare-it-Office-Photos-E1043373.htm
# 3           /Photos/Codup-Office-Photos-E2226886.htm
# 4  /Photos/Markelytics-Solutions-Office-Photos-E8...
#
#                              overview.allReviewsLink  \
# 0          /Reviews/Modus-Group-Reviews-E2183810.htm
# 1   /Reviews/Boehringer-Ingelheim-Reviews-E10416.htm
# 2       /Reviews/Immobiliare-it-Reviews-E1043373.htm
# 3                /Reviews/Codup-Reviews-E2226886.htm
# 4  /Reviews/Markelytics-Solutions-Reviews-E851555...
#
#                             overview.allSalariesLink  overview.foundedYear  \
# 0          /Salary/Modus-Group-Salaries-E2183810.htm                  1993
# 1   /Salary/Boehringer-Ingelheim-Salaries-E10416.htm                  1885
# 2       /Salary/Immobiliare-it-Salaries-E1043373.htm                     0
# 3                /Salary/Codup-Salaries-E2226886.htm                     0
# 4  /Salary/Markelytics-Solutions-Salaries-E851555...                  2003
#
#                    overview.hq                      overview.industry  \
# 0           Vilnius, Lithuania  Investment Banking & Asset Management
# 1  Ingelheim am Rhein, Germany              Biotech & Pharmaceuticals
# 2                MILANO, Italy                                    NaN
# 3            Karachi, Pakistan                                    NaN
# 4             Bangalore, India                             Consulting
#
#    overview.industryId          overview.revenue            overview.sector  \
# 0               200053  Unknown / Non-Applicable                    Finance
# 1               200021   £5 to £10 billion (GBP)  Biotech & Pharmaceuticals
# 2                    0  £25 to £50 million (GBP)                        NaN
# 3                    0  Unknown / Non-Applicable                        NaN
# 4               200028  Unknown / Non-Applicable          Business Services
#
#    overview.sectorId          overview.size overview.stock      overview.type  \
# 0              10010  501 to 1000 employees            NaN  Company - Private
# 1              10005       10000+ employees            NaN  Company - Private
# 2                  0   201 to 500 employees            NaN  Company - Private
# 3                  0      1 to 50 employees            NaN  Company - Private
# 4              10006   201 to 500 employees            NaN  Company - Private
#
#                                 overview.description overview.mission  \
# 0  We are the drivers of the future who offer a g...              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#                overview.website overview.allVideosLink  overview.competitors  \
# 0               www.modus.group                    NaN                   NaN
# 1  www.boehringer-ingelheim.com                    NaN                   NaN
# 2                           NaN                    NaN                   NaN
# 3                           NaN                    NaN                   NaN
# 4                           NaN                    NaN                   NaN
#
#   overview.companyVideo  photos         rating.ceo.name rating.ceo.photo  \
# 0                   NaN  1687.0     Liudas Liutkevičius              NaN
# 1                   NaN  1688.0  Hubertus von Baumbach               NaN
# 2                   NaN     NaN                     NaN              NaN
# 3                   NaN     NaN                     NaN              NaN
# 4                   NaN     NaN                     NaN              NaN
#
#   rating.ceo.photo2x  rating.ceo.ratingsCount  rating.ceoApproval  \
# 0                NaN                      0.0                -0.1
# 1                NaN                    123.0                 0.8
# 2                NaN                      0.0                -1.0
# 3                NaN                      0.0                -1.0
# 4                NaN                      0.0                -1.0
#
#    rating.recommendToFriend  rating.starRating  reviews  \
# 0                     -0.10               -0.1     2801
# 1                      0.76                3.8     2802
# 2                      0.47                2.4     2803
# 3                      0.00                1.5     2804
# 4                      0.67                3.5     2805
#
#   salary.country.cc3LetterISO salary.country.ccISO  \
# 0                         NaN                  NaN
# 1                         GBR                   GB
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
#
#   salary.country.continent.continentCode  \
# 0                                    NaN
# 1                                     EU
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   salary.country.continent.continentName  salary.country.continent.id  \
# 0                                    NaN                          NaN
# 1                                 Europe                          4.0
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
#
#   salary.country.continent.new salary.country.countryFIPS  \
# 0                          NaN                        NaN
# 1                        False                         UK
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#   salary.country.currency.currencyCode  \
# 0                                  NaN
# 1                                  GBP
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    salary.country.currency.defaultFractionDigits  \
# 0                                            NaN
# 1                                            2.0
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   salary.country.currency.displayName  salary.country.currency.id  \
# 0                                 NaN                         NaN
# 1          United Kingdom Pound (GBP)                         2.0
# 2                                 NaN                         NaN
# 3                                 NaN                         NaN
# 4                                 NaN                         NaN
#
#   salary.country.currency.name salary.country.currency.negativeTemplate  \
# 0                          NaN                                      NaN
# 1         United Kingdom Pound                                     $(#)
# 2                          NaN                                      NaN
# 3                          NaN                                      NaN
# 4                          NaN                                      NaN
#
#   salary.country.currency.new salary.country.currency.positiveTemplate  \
# 0                         NaN                                      NaN
# 1                       False                                       $#
# 2                         NaN                                      NaN
# 3                         NaN                                      NaN
# 4                         NaN                                      NaN
#
#   salary.country.currency.symbol salary.country.currencyCode  \
# 0                            NaN                         NaN
# 1                        &pound;                         GBP
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#   salary.country.defaultLocale salary.country.defaultName  \
# 0                          NaN                        NaN
# 1                        en_UK             United Kingdom
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#   salary.country.defaultShortName salary.country.employerSolutionsCountry  \
# 0                             NaN                                     NaN
# 1                  United Kingdom                                    True
# 2                             NaN                                     NaN
# 3                             NaN                                     NaN
# 4                             NaN                                     NaN
#
#    salary.country.id salary.country.longName salary.country.major  \
# 0                NaN                     NaN                  NaN
# 1                2.0          United Kingdom                 True
# 2                NaN                     NaN                  NaN
# 3                NaN                     NaN                  NaN
# 4                NaN                     NaN                  NaN
#
#   salary.country.name salary.country.new  salary.country.population  \
# 0                 NaN                NaN                        NaN
# 1      United Kingdom              False                 60363602.0
# 2                 NaN                NaN                        NaN
# 3                 NaN                NaN                        NaN
# 4                 NaN                NaN                        NaN
#
#   salary.country.shortName salary.country.tld salary.country.type  \
# 0                      NaN                NaN                 NaN
# 1                       UK                .uk                   N
# 2                      NaN                NaN                 NaN
# 3                      NaN                NaN                 NaN
# 4                      NaN                NaN                 NaN
#
#   salary.country.uniqueName salary.country.usaCentricDisplayName  \
# 0                       NaN                                  NaN
# 1            United Kingdom                       United Kingdom
# 2                       NaN                                  NaN
# 3                       NaN                                  NaN
# 4                       NaN                                  NaN
#
#   salary.currency.currencyCode  salary.currency.defaultFractionDigits  \
# 0                          NaN                                    NaN
# 1                          GBP                                    2.0
# 2                          NaN                                    NaN
# 3                          NaN                                    NaN
# 4                          NaN                                    NaN
#
#   salary.currency.displayName  salary.currency.id  salary.currency.name  \
# 0                         NaN                 NaN                   NaN
# 1  United Kingdom Pound (GBP)                 2.0  United Kingdom Pound
# 2                         NaN                 NaN                   NaN
# 3                         NaN                 NaN                   NaN
# 4                         NaN                 NaN                   NaN
#
#   salary.currency.negativeTemplate salary.currency.new  \
# 0                              NaN                 NaN
# 1                             $(#)               False
# 2                              NaN                 NaN
# 3                              NaN                 NaN
# 4                              NaN                 NaN
#
#   salary.currency.positiveTemplate salary.currency.symbol  \
# 0                              NaN                    NaN
# 1                               $#                &pound;
# 2                              NaN                    NaN
# 3                              NaN                    NaN
# 4                              NaN                    NaN
#
#   salary.lastSalaryDate  salary.salaries  wwfu
# 0                   NaN           2483.0   NaN
# 1   2019-10-14T06:05:58           2484.0   NaN
# 2                   NaN           2485.0   NaN
# 3                   NaN           2486.0   NaN
# 4                   NaN           2487.0   NaN

# %%
df.dtypes
# Out:
# benefits.benefitRatingDecimal                                   float64
# benefits.comments                                               float64
# benefits.highlights                                             float64
# benefits.numRatings                                               int64
# benefits.employerSummary                                         object
# breadCrumbs                                                       int64
# gaTrackerData.category                                            int64
# gaTrackerData.empId                                               int64
# gaTrackerData.empName                                            object
# gaTrackerData.empSize                                            object
# gaTrackerData.expired                                              bool
# gaTrackerData.industry                                           object
# gaTrackerData.industryId                                          int64
# gaTrackerData.jobId.long                                        float64
# gaTrackerData.jobId.int                                         float64
# gaTrackerData.jobTitle                                           object
# gaTrackerData.location                                           object
# gaTrackerData.locationId                                          int64
# gaTrackerData.locationType                                       object
# gaTrackerData.pageRequestGuid.guid                               object
# gaTrackerData.pageRequestGuid.guidValid                            bool
# gaTrackerData.pageRequestGuid.part1                               int64
# gaTrackerData.pageRequestGuid.part2                               int64
# gaTrackerData.sector                                             object
# gaTrackerData.sectorId                                            int64
# gaTrackerData.profileConversionTrackingParams.trackingCAT        object
# gaTrackerData.profileConversionTrackingParams.trackingSRC       float64
# gaTrackerData.profileConversionTrackingParams.trackingXSP       float64
# gaTrackerData.jobViewTrackingResult.jobViewDisplayTimeMillis    float64
# gaTrackerData.jobViewTrackingResult.requiresTracking             object
# gaTrackerData.jobViewTrackingResult.trackingUrl                  object
# header.adOrderId                                                  int64
# header.advertiserType                                            object
# header.applicationId                                              int64
# header.applyButtonDisabled                                         bool
# header.applyUrl                                                  object
# header.blur                                                        bool
# header.coverPhoto                                                object
# header.easyApply                                                   bool
# header.employerId                                                 int64
# header.employerName                                              object
# header.expired                                                     bool
# header.gocId                                                      int64
# header.hideCEOInfo                                                 bool
# header.jobTitle                                                  object
# header.locId                                                      int64
# header.location                                                  object
# header.locationType                                              object
# header.logo                                                      object
# header.logo2x                                                    object
# header.organic                                                     bool
# header.overviewUrl                                               object
# header.posted                                                    object
# header.rating                                                   float64
# header.saved                                                       bool
# header.savedJobId                                                 int64
# header.sgocId                                                     int64
# header.sponsored                                                   bool
# header.userAdmin                                                   bool
# header.uxApplyType                                               object
# header.featuredVideo                                             object
# header.normalizedJobTitle                                        object
# header.urgencyLabel                                              object
# header.urgencyLabelForMessage                                    object
# header.urgencyMessage                                            object
# header.needsCommission                                           object
# header.payHigh                                                  float64
# header.payLow                                                   float64
# header.payMed                                                   float64
# header.payPeriod                                                 object
# header.salaryHigh                                               float64
# header.salaryLow                                                float64
# header.salarySource                                              object
# job.description                                                  object
# job.discoverDate                                                 object
# job.eolHashCode                                                   int64
# job.importConfigId                                                int64
# job.jobReqId.long                                               float64
# job.jobReqId.int                                                float64
# job.jobSource                                                    object
# job.jobTitleId                                                    int64
# job.listingId.long                                              float64
# job.listingId.int                                               float64
# map.country                                                      object
# map.employerName                                                 object
# map.lat                                                         float64
# map.lng                                                         float64
# map.location                                                     object
# map.address                                                      object
# map.postalCode                                                   object
# overview.allBenefitsLink                                         object
# overview.allPhotosLink                                           object
# overview.allReviewsLink                                          object
# overview.allSalariesLink                                         object
# overview.foundedYear                                              int64
# overview.hq                                                      object
# overview.industry                                                object
# overview.industryId                                               int64
# overview.revenue                                                 object
# overview.sector                                                  object
# overview.sectorId                                                 int64
# overview.size                                                    object
# overview.stock                                                   object
# overview.type                                                    object
# overview.description                                             object
# overview.mission                                                 object
# overview.website                                                 object
# overview.allVideosLink                                           object
# overview.competitors                                            float64
# overview.companyVideo                                            object
# photos                                                          float64
# rating.ceo.name                                                  object
# rating.ceo.photo                                                 object
# rating.ceo.photo2x                                               object
# rating.ceo.ratingsCount                                         float64
# rating.ceoApproval                                              float64
# rating.recommendToFriend                                        float64
# rating.starRating                                               float64
# reviews                                                           int64
# salary.country.cc3LetterISO                                      object
# salary.country.ccISO                                             object
# salary.country.continent.continentCode                           object
# salary.country.continent.continentName                           object
# salary.country.continent.id                                     float64
# salary.country.continent.new                                     object
# salary.country.countryFIPS                                       object
# salary.country.currency.currencyCode                             object
# salary.country.currency.defaultFractionDigits                   float64
# salary.country.currency.displayName                              object
# salary.country.currency.id                                      float64
# salary.country.currency.name                                     object
# salary.country.currency.negativeTemplate                         object
# salary.country.currency.new                                      object
# salary.country.currency.positiveTemplate                         object
# salary.country.currency.symbol                                   object
# salary.country.currencyCode                                      object
# salary.country.defaultLocale                                     object
# salary.country.defaultName                                       object
# salary.country.defaultShortName                                  object
# salary.country.employerSolutionsCountry                          object
# salary.country.id                                               float64
# salary.country.longName                                          object
# salary.country.major                                             object
# salary.country.name                                              object
# salary.country.new                                               object
# salary.country.population                                       float64
# salary.country.shortName                                         object
# salary.country.tld                                               object
# salary.country.type                                              object
# salary.country.uniqueName                                        object
# salary.country.usaCentricDisplayName                             object
# salary.currency.currencyCode                                     object
# salary.currency.defaultFractionDigits                           float64
# salary.currency.displayName                                      object
# salary.currency.id                                              float64
# salary.currency.name                                             object
# salary.currency.negativeTemplate                                 object
# salary.currency.new                                              object
# salary.currency.positiveTemplate                                 object
# salary.currency.symbol                                           object
# salary.lastSalaryDate                                            object
# salary.salaries                                                 float64
# wwfu                                                            float64
# dtype: object

# %%
df.describe()
# Out:
#        benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# count                  165290.000000      165289.000000        165289.000000
# mean                        1.387690       82645.000000         82645.000000
# std                         1.826381       47714.968659         47714.968659
# min                         0.000000           1.000000             1.000000
# 25%                         0.000000       41323.000000         41323.000000
# 50%                         0.000000       82645.000000         82645.000000
# 75%                         3.504717      123967.000000        123967.000000
# max                         5.000000      165289.000000        165289.000000
#
#        benefits.numRatings    breadCrumbs  gaTrackerData.category  \
# count        165290.000000  165290.000000           165290.000000
# mean             17.650342   82645.500000             2476.188614
# std              49.901598   47715.257335             6098.395811
# min               0.000000       1.000000               -1.000000
# 25%               0.000000   41323.250000               -1.000000
# 50%               0.000000   82645.500000               -1.000000
# 75%               6.000000  123967.750000               -1.000000
# max             596.000000  165290.000000            30165.000000
#
#        gaTrackerData.empId  gaTrackerData.industryId  \
# count         1.652900e+05             165290.000000
# mean          6.945812e+05             142681.566731
# std           8.862075e+05              90479.876651
# min           0.000000e+00                  0.000000
# 25%           5.632000e+03                  0.000000
# 50%           3.043920e+05             200048.000000
# 75%           1.107358e+06             200063.000000
# max           3.102014e+06             200147.000000
#
#        gaTrackerData.jobId.long  gaTrackerData.jobId.int  \
# count              1.650440e+05             2.460000e+02
# mean               3.329226e+09             1.754135e+09
# std                1.167657e+08             3.473246e+08
# min                2.208549e+09             3.276949e+08
# 25%                3.303018e+09             1.756631e+09
# 50%                3.370946e+09             1.904030e+09
# 75%                3.399873e+09             1.957060e+09
# max                3.412782e+09             2.022056e+09
#
#        gaTrackerData.locationId  gaTrackerData.pageRequestGuid.part1  \
# count              1.652900e+05                         1.652900e+05
# mean               2.548963e+06                         1.573422e+12
# std                1.116096e+06                         9.163820e+06
# min               -1.000000e+00                         1.573401e+12
# 25%                2.302160e+06                         1.573415e+12
# 50%                2.739035e+06                         1.573425e+12
# 75%                3.174503e+06                         1.573429e+12
# max                5.021990e+06                         1.573433e+12
#
#        gaTrackerData.pageRequestGuid.part2  gaTrackerData.sectorId  \
# count                         1.652900e+05           165290.000000
# mean                         -6.921523e+18             7142.386557
# std                           1.327411e+18             4527.120950
# min                          -9.223346e+18                0.000000
# 25%                          -8.067385e+18                0.000000
# 50%                          -6.926075e+18            10010.000000
# 75%                          -5.778284e+18            10013.000000
# max                          -4.611694e+18            10025.000000
#
#        gaTrackerData.profileConversionTrackingParams.trackingSRC  \
# count                                       1.765700e+04
# mean                                        7.695416e+06
# std                                         1.449757e+06
# min                                         5.876256e+06
# 25%                                         6.173533e+06
# 50%                                         8.198932e+06
# 75%                                         9.170837e+06
# max                                         9.745460e+06
#
#        gaTrackerData.profileConversionTrackingParams.trackingXSP  \
# count                                       3.512200e+04
# mean                                        4.374331e+06
# std                                         3.985421e+04
# min                                         4.342948e+06
# 25%                                         4.356181e+06
# 50%                                         4.358328e+06
# 75%                                         4.362617e+06
# max                                         4.596461e+06
#
#        gaTrackerData.jobViewTrackingResult.jobViewDisplayTimeMillis  \
# count                                             2251.0
# mean                                              2000.0
# std                                                  0.0
# min                                               2000.0
# 25%                                               2000.0
# 50%                                               2000.0
# 75%                                               2000.0
# max                                               2000.0
#
#        header.adOrderId  header.applicationId  header.employerId  \
# count     165290.000000              165290.0       1.652900e+05
# mean      369799.327455                   0.0       6.947220e+05
# std       226927.978397                   0.0       8.861269e+05
# min            0.000000                   0.0       0.000000e+00
# 25%       148364.000000                   0.0       5.632000e+03
# 50%       437149.000000                   0.0       3.047010e+05
# 75%       444429.000000                   0.0       1.107358e+06
# max       815345.000000                   0.0       3.102014e+06
#
#         header.gocId  header.locId  header.rating  header.savedJobId  \
# count  165290.000000  1.652900e+05  165290.000000           165290.0
# mean    24739.706619  2.549172e+06       2.956646                0.0
# std     60945.108260  1.115618e+06       1.612910                0.0
# min        -1.000000  0.000000e+00      -0.100000                0.0
# 25%        -1.000000  2.302160e+06       2.800000                0.0
# 50%        -1.000000  2.739035e+06       3.600000                0.0
# 75%        -1.000000  3.174503e+06       4.000000                0.0
# max    302663.000000  5.021990e+06       5.000000                0.0
#
#        header.sgocId  header.payHigh  header.payLow  header.payMed  \
# count  165290.000000     3662.000000    3662.000000    3642.000000
# mean        0.128544   115832.403605   77825.276898   95296.689182
# std        11.403713    42077.284501   30736.395180   34862.443369
# min         0.000000       13.000000      10.000000      95.000000
# 25%         0.000000    85217.500000   55283.500000   69653.750000
# 50%         0.000000   109630.500000   72435.000000   88507.500000
# 75%         0.000000   140000.000000   95966.000000  115701.750000
# max      1021.000000   376948.000000  236650.000000  292515.000000
#
#        header.salaryHigh  header.salaryLow  job.eolHashCode  \
# count        3662.000000       3662.000000     1.652900e+05
# mean       115832.403605      77825.276898     1.111103e+06
# std         42077.284501      30736.395180     1.231548e+09
# min            13.000000         10.000000    -2.147479e+09
# 25%         85217.500000      55283.500000    -1.057640e+09
# 50%        109630.500000      72435.000000     0.000000e+00
# 75%        140000.000000      95966.000000     1.064102e+09
# max        376948.000000     236650.000000     2.147474e+09
#
#        job.importConfigId  job.jobReqId.long  job.jobReqId.int  \
# count       165290.000000       1.652690e+05      2.100000e+01
# mean        185566.329518       4.150408e+09      1.449378e+09
# std          64349.629188       7.624523e+07      7.453432e+08
# min             69.000000       2.218864e+09      0.000000e+00
# 25%         140219.000000       4.125768e+09      1.483060e+09
# 50%         193161.000000       4.175448e+09      1.632784e+09
# 75%         243633.000000       4.197237e+09      2.003916e+09
# max         298387.000000       4.211234e+09      2.052380e+09
#
#        job.jobTitleId  job.listingId.long  job.listingId.int        map.lat  \
# count    1.652900e+05        1.650440e+05       2.460000e+02  165290.000000
# mean     1.772416e+05        3.329226e+09       1.754135e+09      26.499080
# std      5.917228e+05        1.167657e+08       3.473246e+08      26.013832
# min     -1.000000e+00        2.208549e+09       3.276949e+08     -77.850000
# 25%     -1.000000e+00        3.303018e+09       1.756631e+09       2.922800
# 50%      4.279000e+03        3.370946e+09       1.904030e+09      33.823400
# 75%      6.150200e+04        3.399873e+09       1.957060e+09      48.866700
# max      5.267740e+06        3.412782e+09       2.022056e+09      67.183300
#
#              map.lng  overview.foundedYear  overview.industryId  \
# count  165290.000000         165290.000000        165290.000000
# mean       29.642232           1273.873422        142681.566731
# std        62.586654            942.425948         90479.876651
# min      -171.983300              0.000000             0.000000
# 25%         0.000000              0.000000             0.000000
# 50%        12.133300           1947.000000        200048.000000
# 75%        77.587300           1998.000000        200063.000000
# max       177.366700           2019.000000        200147.000000
#
#        overview.sectorId  overview.competitors         photos  \
# count      165290.000000          47988.000000  101429.000000
# mean         7142.386557          23994.500000   50715.000000
# std          4527.120950          13853.086696   29280.174564
# min             0.000000              1.000000       1.000000
# 25%             0.000000          11997.750000   25358.000000
# 50%         10010.000000          23994.500000   50715.000000
# 75%         10013.000000          35991.250000   76072.000000
# max         10025.000000          47988.000000  101429.000000
#
#        rating.ceo.ratingsCount  rating.ceoApproval  rating.recommendToFriend  \
# count            146899.000000       146899.000000             146899.000000
# mean                728.972171            0.413151                  0.625625
# std                2924.011815            0.712426                  0.316064
# min                   0.000000           -1.000000                 -0.100000
# 25%                   0.000000           -0.100000                  0.540000
# 50%                  20.000000            0.780000                  0.720000
# 75%                 166.000000            0.910000                  0.820000
# max               19796.000000            1.000000                  1.000000
#
#        rating.starRating        reviews  salary.country.continent.id  \
# count      146899.000000  165290.000000                      76777.0
# mean            3.326927   82645.500000                          4.0
# std             1.301878   47715.257335                          0.0
# min            -0.100000       1.000000                          4.0
# 25%             3.200000   41323.250000                          4.0
# 50%             3.700000   82645.500000                          4.0
# 75%             4.000000  123967.750000                          4.0
# max             5.000000  165290.000000                          4.0
#
#        salary.country.currency.defaultFractionDigits  \
# count                                        76777.0
# mean                                             2.0
# std                                              0.0
# min                                              2.0
# 25%                                              2.0
# 50%                                              2.0
# 75%                                              2.0
# max                                              2.0
#
#        salary.country.currency.id  salary.country.id  \
# count                     76777.0            76777.0
# mean                          2.0                2.0
# std                           0.0                0.0
# min                           2.0                2.0
# 25%                           2.0                2.0
# 50%                           2.0                2.0
# 75%                           2.0                2.0
# max                           2.0                2.0
#
#        salary.country.population  salary.currency.defaultFractionDigits  \
# count                    76777.0                                76777.0
# mean                  60363602.0                                    2.0
# std                          0.0                                    0.0
# min                   60363602.0                                    2.0
# 25%                   60363602.0                                    2.0
# 50%                   60363602.0                                    2.0
# 75%                   60363602.0                                    2.0
# max                   60363602.0                                    2.0
#
#        salary.currency.id  salary.salaries          wwfu
# count        76777.000000    147149.000000  18741.000000
# mean             2.037238     73575.000000   9371.000000
# std              1.292106     42478.401718   5410.205033
# min              1.000000         1.000000      1.000000
# 25%              2.000000     36788.000000   4686.000000
# 50%              2.000000     73575.000000   9371.000000
# 75%              2.000000    110362.000000  14056.000000
# max             47.000000    147149.000000  18741.000000

# %%
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)

# %% [markdown]
# Como el dataset dispone de bastantes filas pandas solo me permite ver un numero limitado, asi que opte por desplegar todas las filas y poder verlas todas.

# %%
df.isnull().sum()
# Out:
# benefits.benefitRatingDecimal                                        0
# benefits.comments                                                    1
# benefits.highlights                                                  1
# benefits.numRatings                                                  0
# benefits.employerSummary                                        159541
# breadCrumbs                                                          0
# gaTrackerData.category                                               0
# gaTrackerData.empId                                                  0
# gaTrackerData.empName                                            18209
# gaTrackerData.empSize                                            18209
# gaTrackerData.expired                                                0
# gaTrackerData.industry                                           47405
# gaTrackerData.industryId                                             0
# gaTrackerData.jobId.long                                           246
# gaTrackerData.jobId.int                                         165044
# gaTrackerData.jobTitle                                               0
# gaTrackerData.location                                           70283
# gaTrackerData.locationId                                             0
# gaTrackerData.locationType                                           0
# gaTrackerData.pageRequestGuid.guid                                   0
# gaTrackerData.pageRequestGuid.guidValid                              0
# gaTrackerData.pageRequestGuid.part1                                  0
# gaTrackerData.pageRequestGuid.part2                                  0
# gaTrackerData.sector                                             47373
# gaTrackerData.sectorId                                               0
# gaTrackerData.profileConversionTrackingParams.trackingCAT       147633
# gaTrackerData.profileConversionTrackingParams.trackingSRC       147633
# gaTrackerData.profileConversionTrackingParams.trackingXSP       130168
# gaTrackerData.jobViewTrackingResult.jobViewDisplayTimeMillis    163039
# gaTrackerData.jobViewTrackingResult.requiresTracking            163039
# gaTrackerData.jobViewTrackingResult.trackingUrl                 163039
# header.adOrderId                                                     0
# header.advertiserType                                             1905
# header.applicationId                                                 0
# header.applyButtonDisabled                                           0
# header.applyUrl                                                      0
# header.blur                                                          0
# header.coverPhoto                                                    0
# header.easyApply                                                     0
# header.employerId                                                    0
# header.employerName                                               3245
# header.expired                                                       0
# header.gocId                                                         0
# header.hideCEOInfo                                                   0
# header.jobTitle                                                      0
# header.locId                                                         0
# header.location                                                      5
# header.locationType                                                 23
# header.logo                                                      32220
# header.logo2x                                                    32220
# header.organic                                                       0
# header.overviewUrl                                                   0
# header.posted                                                        0
# header.rating                                                        0
# header.saved                                                         0
# header.savedJobId                                                    0
# header.sgocId                                                        0
# header.sponsored                                                     0
# header.userAdmin                                                     0
# header.uxApplyType                                              147652
# header.featuredVideo                                            151625
# header.normalizedJobTitle                                       136135
# header.urgencyLabel                                             160769
# header.urgencyLabelForMessage                                   160769
# header.urgencyMessage                                           160769
# header.needsCommission                                          161628
# header.payHigh                                                  161628
# header.payLow                                                   161628
# header.payMed                                                   161648
# header.payPeriod                                                161653
# header.salaryHigh                                               161628
# header.salaryLow                                                161628
# header.salarySource                                             161628
# job.description                                                      4
# job.discoverDate                                                     0
# job.eolHashCode                                                      0
# job.importConfigId                                                   0
# job.jobReqId.long                                                   21
# job.jobReqId.int                                                165269
# job.jobSource                                                        0
# job.jobTitleId                                                       0
# job.listingId.long                                                 246
# job.listingId.int                                               165044
# map.country                                                      50028
# map.employerName                                                 18141
# map.lat                                                              0
# map.lng                                                              0
# map.location                                                         5
# map.address                                                     151108
# map.postalCode                                                  151317
# overview.allBenefitsLink                                         18209
# overview.allPhotosLink                                           18209
# overview.allReviewsLink                                          18209
# overview.allSalariesLink                                         18209
# overview.foundedYear                                                 0
# overview.hq                                                      19367
# overview.industry                                                47405
# overview.industryId                                                  0
# overview.revenue                                                 18209
# overview.sector                                                  47373
# overview.sectorId                                                    0
# overview.size                                                    18209
# overview.stock                                                  118933
# overview.type                                                    18209
# overview.description                                             78331
# overview.mission                                                113134
# overview.website                                                 65106
# overview.allVideosLink                                          132449
# overview.competitors                                            117302
# overview.companyVideo                                           138870
# photos                                                           63861
# rating.ceo.name                                                  52956
# rating.ceo.photo                                                 85714
# rating.ceo.photo2x                                               85714
# rating.ceo.ratingsCount                                          18391
# rating.ceoApproval                                               18391
# rating.recommendToFriend                                         18391
# rating.starRating                                                18391
# reviews                                                              0
# salary.country.cc3LetterISO                                      88513
# salary.country.ccISO                                             88513
# salary.country.continent.continentCode                           88513
# salary.country.continent.continentName                           88513
# salary.country.continent.id                                      88513
# salary.country.continent.new                                     88513
# salary.country.countryFIPS                                       88513
# salary.country.currency.currencyCode                             88513
# salary.country.currency.defaultFractionDigits                    88513
# salary.country.currency.displayName                              88513
# salary.country.currency.id                                       88513
# salary.country.currency.name                                     88513
# salary.country.currency.negativeTemplate                         88513
# salary.country.currency.new                                      88513
# salary.country.currency.positiveTemplate                         88513
# salary.country.currency.symbol                                   88513
# salary.country.currencyCode                                      88513
# salary.country.defaultLocale                                     88513
# salary.country.defaultName                                       88513
# salary.country.defaultShortName                                  88513
# salary.country.employerSolutionsCountry                          88513
# salary.country.id                                                88513
# salary.country.longName                                          88513
# salary.country.major                                             88513
# salary.country.name                                              88513
# salary.country.new                                               88513
# salary.country.population                                        88513
# salary.country.shortName                                         88513
# salary.country.tld                                               88513
# salary.country.type                                              88513
# salary.country.uniqueName                                        88513
# salary.country.usaCentricDisplayName                             88513
# salary.currency.currencyCode                                     88513
# salary.currency.defaultFractionDigits                            88513
# salary.currency.displayName                                      88513
# salary.currency.id                                               88513
# salary.currency.name                                             88513
# salary.currency.negativeTemplate                                 88513
# salary.currency.new                                              88513
# salary.currency.positiveTemplate                                 88513
# salary.currency.symbol                                           88513
# salary.lastSalaryDate                                            88513
# salary.salaries                                                  18141
# wwfu                                                            146549
# dtype: int64

# %%
deleted_columns = ['breadCrumbs','gaTrackerData.category','gaTrackerData.empId','gaTrackerData.empSize','gaTrackerData.expired','gaTrackerData.industryId','gaTrackerData.jobId.long','gaTrackerData.jobId.int','gaTrackerData.locationId','gaTrackerData.locationType','gaTrackerData.pageRequestGuid.guid','gaTrackerData.pageRequestGuid.guidValid','gaTrackerData.pageRequestGuid.part1','gaTrackerData.pageRequestGuid.part2','gaTrackerData.sectorId','gaTrackerData.profileConversionTrackingParams.trackingCAT','gaTrackerData.profileConversionTrackingParams.trackingSRC','gaTrackerData.profileConversionTrackingParams.trackingXSP','gaTrackerData.jobViewTrackingResult.jobViewDisplayTimeMillis','gaTrackerData.jobViewTrackingResult.requiresTracking','gaTrackerData.jobViewTrackingResult.trackingUrl','header.adOrderId','header.advertiserType','header.applicationId','header.applyButtonDisabled','header.applyUrl','header.blur','header.coverPhoto','header.easyApply','header.employerId','header.expired','header.gocId','header.hideCEOInfo','header.locId','header.locationType','header.logo','header.logo2x','header.organic','header.overviewUrl','header.rating','header.saved','header.savedJobId','header.sgocId','header.sponsored','header.userAdmin','header.uxApplyType','header.featuredVideo','header.urgencyLabel','header.urgencyLabelForMessage','header.urgencyMessage','header.needsCommission','header.payHigh','header.payLow','header.payMed','header.payPeriod','header.salaryHigh','header.salaryLow','header.salarySource','job.eolHashCode','job.importConfigId','job.jobReqId.long','job.jobReqId.int','job.jobTitleId','job.listingId.long','job.listingId.int','map.address','map.postalCode','overview.allBenefitsLink','overview.allPhotosLink','overview.allReviewsLink','overview.allSalariesLink','overview.industryId','overview.sectorId','overview.stock','overview.mission','overview.allVideosLink','overview.competitors','overview.companyVideo','photos','rating.ceo.photo','rating.ceo.photo2x','rating.ceo.ratingsCount','rating.ceoApproval','rating.recommendToFriend','salary.country.cc3LetterISO','salary.country.ccISO','salary.country.continent.continentCode','salary.country.continent.continentName','salary.country.continent.id','salary.country.continent.new','salary.country.countryFIPS','salary.country.currency.currencyCode','salary.country.currency.defaultFractionDigits','salary.country.currency.displayName','salary.country.currency.id','salary.country.currency.negativeTemplate','salary.country.currency.new','salary.country.currency.positiveTemplate','salary.country.currency.symbol','salary.country.currencyCode','salary.country.defaultLocale','salary.country.defaultShortName','salary.country.employerSolutionsCountry','salary.country.id','salary.country.longName','salary.country.major','salary.country.name','salary.country.new','salary.country.population','salary.country.shortName','salary.country.tld','salary.country.type','salary.country.uniqueName','salary.country.usaCentricDisplayName','salary.currency.currencyCode','salary.currency.defaultFractionDigits','salary.currency.displayName','salary.currency.id','salary.currency.name','salary.currency.negativeTemplate','salary.currency.new','salary.currency.positiveTemplate','salary.currency.symbol','salary.lastSalaryDate','wwfu']

# %%
df_without_columns = df.drop(columns = deleted_columns)

# %% [markdown]
# Elimine estas columnas por los criterios que determine para mi objetivo principal, de las cuales vi que no eran necesarias.

# %%
df_without_columns.head()
# Out:
#    benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.0             2801.0               2801.0
# 1                            4.0             2802.0               2802.0
# 2                            0.0             2803.0               2803.0
# 3                            0.0             2804.0               2804.0
# 4                            0.0             2805.0               2805.0
#
#    benefits.numRatings benefits.employerSummary  gaTrackerData.empName  \
# 0                    0                      NaN            Modus Group
# 1                    3                      NaN   Boehringer Ingelheim
# 2                    0                      NaN        Immobiliare.it
# 3                    0                      NaN                  Codup
# 4                    0                      NaN  Markelytics Solutions
#
#                   gaTrackerData.industry  \
# 0  Investment Banking & Asset Management
# 1              Biotech & Pharmaceuticals
# 2                                    NaN
# 3                                    NaN
# 4                             Consulting
#
#                               gaTrackerData.jobTitle gaTrackerData.location  \
# 0                 Biogas Project Development Manager                 Warsaw
# 1  Quality Manager - Boehringer Ingelheim Healthc...                    NaN
# 2     Senior Software Engineer (PHP, Elixir, Python)                 Milano
# 3                                Senior SQA Engineer                Karachi
# 4                                   Research Manager              Bengaluru
#
#         gaTrackerData.sector          header.employerName  \
# 0                    Finance                  Modus Group
# 1  Biotech & Pharmaceuticals         Boehringer Ingelheim
# 2                        NaN               Immobiliare.it
# 3                        NaN                        Codup
# 4          Business Services  MARKELYTICS SOLUTIONS INDIA
#
#                                      header.jobTitle header.location  \
# 0                 Biogas Project Development Manager          Warsaw
# 1  Quality Manager - Boehringer Ingelheim Healthc...           Porto
# 2     Senior Software Engineer (PHP, Elixir, Python)           Milan
# 3                                Senior SQA Engineer         Karāchi
# 4                                   Research Manager       Bengaluru
#
#   header.posted header.normalizedJobTitle  \
# 0  Oct 24, 2019                       NaN
# 1   Nov 4, 2019                       NaN
# 2  Oct 28, 2019                       NaN
# 3   Nov 4, 2019                       NaN
# 4   Nov 1, 2019                       NaN
#
#                                      job.description     job.discoverDate  \
# 0  We are the drivers of the future who offer a g...  2019-10-24T04:52:23
# 1  <strong></strong>\n<br/><br/>\n<strong></stron...  2019-11-04T03:59:14
# 2  Dottori.it &egrave; il motore di ricerca che t...  2019-10-28T12:48:55
# 3  Codup is looking for a Senior SQA Engineer for...  2019-11-04T07:00:20
# 4  <strong>Department:</strong> Research &amp; Op...  2019-11-01T13:40:48
#
#               job.jobSource map.country       map.employerName  map.lat  \
# 0            WorkableHR.com      Poland            Modus Group  52.2500
# 1                     taleo         NaN   Boehringer Ingelheim  41.1500
# 2  Indeed XML Feed Employer       Italy        Immobiliare.it   45.4667
# 3    Indeed XML Feed Dradis          PK                  Codup  24.8667
# 4  Indeed XML Feed Employer          IN  Markelytics Solutions  12.9670
#
#    map.lng map.location  overview.foundedYear                  overview.hq  \
# 0  21.0000       Warsaw                  1993           Vilnius, Lithuania
# 1  -8.6167        Porto                  1885  Ingelheim am Rhein, Germany
# 2   9.2000        Milan                     0                MILANO, Italy
# 3  67.0500      Karāchi                     0            Karachi, Pakistan
# 4  77.5873    Bengaluru                  2003             Bangalore, India
#
#                        overview.industry          overview.revenue  \
# 0  Investment Banking & Asset Management  Unknown / Non-Applicable
# 1              Biotech & Pharmaceuticals   £5 to £10 billion (GBP)
# 2                                    NaN  £25 to £50 million (GBP)
# 3                                    NaN  Unknown / Non-Applicable
# 4                             Consulting  Unknown / Non-Applicable
#
#              overview.sector          overview.size      overview.type  \
# 0                    Finance  501 to 1000 employees  Company - Private
# 1  Biotech & Pharmaceuticals       10000+ employees  Company - Private
# 2                        NaN   201 to 500 employees  Company - Private
# 3                        NaN      1 to 50 employees  Company - Private
# 4          Business Services   201 to 500 employees  Company - Private
#
#                                 overview.description  \
# 0  We are the drivers of the future who offer a g...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                overview.website         rating.ceo.name  rating.starRating  \
# 0               www.modus.group     Liudas Liutkevičius               -0.1
# 1  www.boehringer-ingelheim.com  Hubertus von Baumbach                 3.8
# 2                           NaN                     NaN                2.4
# 3                           NaN                     NaN                1.5
# 4                           NaN                     NaN                3.5
#
#    reviews salary.country.currency.name salary.country.defaultName  \
# 0     2801                          NaN                        NaN
# 1     2802         United Kingdom Pound             United Kingdom
# 2     2803                          NaN                        NaN
# 3     2804                          NaN                        NaN
# 4     2805                          NaN                        NaN
#
#    salary.salaries
# 0           2483.0
# 1           2484.0
# 2           2485.0
# 3           2486.0
# 4           2487.0

# %%
column_formats = df_without_columns.dtypes
print(column_formats)
# Out:
# benefits.benefitRatingDecimal    float64
# benefits.comments                float64
# benefits.highlights              float64
# benefits.numRatings                int64
# benefits.employerSummary          object
# gaTrackerData.empName             object
# gaTrackerData.industry            object
# gaTrackerData.jobTitle            object
# gaTrackerData.location            object
# gaTrackerData.sector              object
# header.employerName               object
# header.jobTitle                   object
# header.location                   object
# header.posted                     object
# header.normalizedJobTitle         object
# job.description                   object
# job.discoverDate                  object
# job.jobSource                     object
# map.country                       object
# map.employerName                  object
# map.lat                          float64
# map.lng                          float64
# map.location                      object
# overview.foundedYear               int64
# overview.hq                       object
# overview.industry                 object
# overview.revenue                  object
# overview.sector                   object
# overview.size                     object
# overview.type                     object
# overview.description              object
# overview.website                  object
# rating.ceo.name                   object
# rating.starRating                float64
# reviews                            int64
# salary.country.currency.name      object
# salary.country.defaultName        object
# salary.salaries                  float64
# dtype: object

# %% [markdown]
# Tablas a utilizar: glassdoor_benefits_highlights.csv, glassdoor_salary_salaries.csv

# %%
df_without_columns.isnull().sum()
# Out:
# benefits.benefitRatingDecimal         0
# benefits.comments                     1
# benefits.highlights                   1
# benefits.numRatings                   0
# benefits.employerSummary         159541
# gaTrackerData.empName             18209
# gaTrackerData.industry            47405
# gaTrackerData.jobTitle                0
# gaTrackerData.location            70283
# gaTrackerData.sector              47373
# header.employerName                3245
# header.jobTitle                       0
# header.location                       5
# header.posted                         0
# header.normalizedJobTitle        136135
# job.description                       4
# job.discoverDate                      0
# job.jobSource                         0
# map.country                       50028
# map.employerName                  18141
# map.lat                               0
# map.lng                               0
# map.location                          5
# overview.foundedYear                  0
# overview.hq                       19367
# overview.industry                 47405
# overview.revenue                  18209
# overview.sector                   47373
# overview.size                     18209
# overview.type                     18209
# overview.description              78331
# overview.website                  65106
# rating.ceo.name                   52956
# rating.starRating                 18391
# reviews                               0
# salary.country.currency.name      88513
# salary.country.defaultName        88513
# salary.salaries                   18141
# dtype: int64
